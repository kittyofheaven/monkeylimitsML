# %%
import pandas as pd

csv_list = [
    'OCR Dataset - Bank Jago.csv',
    'OCR Dataset - BLU.csv',
    'OCR Dataset - Gopay.csv',
    'OCR Dataset - Livin By Mandiri.csv',
    'OCR Dataset - MyBCA.csv',
    'OCR Dataset - OVO.csv',
    'OCR Dataset - Shopee Pay.csv'
]

dfs = []

for csv_file in csv_list:
    df = pd.read_csv('datasets/' + csv_file)
    df['source'] = csv_file 
    dfs.append(df)

df = pd.concat(dfs, ignore_index=True)

df
# Out:
#      Nama File                                          Hasil OCR  \
# 0      Jago_01  Dimsum Nat food\nRp13.500\nID Transaksi\n23878...
# 1      Jago_02  KIOS TALENTA\nRp2.200\nID Transaksi\n234014770...
# 2      Jago_03  Jus Mbak Yuli\nRp11.000\nID Transaksi\n2365882...
# 3      Jago_04  KEDAI YO\nRp6.000\nID Transaksi\n2350877O19\nS...
# 4      Jago_05  SUMARNI, Otomotif\nBOGOR\nRp13.000\nID Transak...
# ..         ...                                                ...
# 337  Shopee_46  8:14 & 9\n<Rincian Pembayaran\nBayar Ke\nTrans...
# 338  Shopee_47  8:08 9\n< Rincian Pembayaran\nBayar Ke\nTransa...
# 339  Shopee_48  8:14 9\n<Rincian Pembayaran\nBayar Ke\nS Shope...
# 340  Shopee_49  9:36 L 00:23\n( Rincian Pembayaran\nBayar Ke\n...
# 341  Shopee_50  10:07 L 31:54\n( Rincian Pembayaran\nBayar Ke\...
#
#                Kategori    Method                        source
# 0    Food and Beverages      QRIS   OCR Dataset - Bank Jago.csv
# 1              Shopping      QRIS   OCR Dataset - Bank Jago.csv
# 2    Food and Beverages      QRIS   OCR Dataset - Bank Jago.csv
# 3    Food and Beverages      QRIS   OCR Dataset - Bank Jago.csv
# 4             Transport      QRIS   OCR Dataset - Bank Jago.csv
# ..                  ...       ...                           ...
# 337            Shopping  E-WALLET  OCR Dataset - Shopee Pay.csv
# 338            Shopping  E-WALLET  OCR Dataset - Shopee Pay.csv
# 339  Food and Beverages  E-WALLET  OCR Dataset - Shopee Pay.csv
# 340            Shopping      QRIS  OCR Dataset - Shopee Pay.csv
# 341            Shopping      QRIS  OCR Dataset - Shopee Pay.csv
#
# [342 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 342 entries, 0 to 341
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Nama File  342 non-null    object
#  1   Hasil OCR  342 non-null    object
#  2   Kategori   320 non-null    object
#  3   Method     320 non-null    object
#  4   source     342 non-null    object
# dtypes: object(5)
# memory usage: 13.5+ KB

# %%
# cek yang null siapa
df.isnull().sum()
# Out:
# Nama File     0
# Hasil OCR     0
# Kategori     22
# Method       22
# source        0
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
#     Nama File                                          Hasil OCR Kategori  \
# 185     ERROR                                              ERROR      NaN
# 221    BCA_30  BCA\nBCA\nRRN\nBCA\nPayment to\nAcquirer\nQRIS...      NaN
# 222    BCA_31  BCA\nBCA\nRRN\nBCA\nPayment to\nAcquirer\nQRIS...      NaN
# 223    BCA_32  BCA\nBCA\nRRN\nBCA\nPayment to\nAcquirer\nQRIS...      NaN
# 224    BCA_33  BCA\nBCA\nBCA\nPayment to\nAcquirer\nRRN\nQRIS...      NaN
# 225    BCA_34  BCA\nBCA\nRRN\nBCA\nPayment to\nAcquirer\nQRIS...      NaN
# 226    BCA_35  BCA\nBCA\nRRN\nBCA\nPayment to\nAcquirer\nQRIS...      NaN
# 227    BCA_36  BCA\nBCA\nBCA\nPayment to\nAcquirer\nRRN\nQRIS...      NaN
# 228    BCA_37  BCA\nBCA\nRRN\nBCA\nPayment to\nAcquirer\nQRIS...      NaN
# 229    BCA_38  BCA\nBCA\nRRN\nBCA\nPayment to\nAcquirer\nQRIS...      NaN
# 230    BCA_39  BCA\n&BCA\nRRN\nBCA\nPayment to\nAcquirer\nQRI...      NaN
# 231    BCA_40  BCA\nBCA\nRRN\nBCA\nPayment to\nAcquirer\nQRIS...      NaN
# 232    BCA_41  BCA\nBCA\nBCA\nRRN\nPayment to\nAcquirer\nQRIS...      NaN
# 233    BCA_42  BCA\nBCA\nRRN\nBCA\nPayment to\nAcquirer\nQRIS...      NaN
# 234    BCA_43  BCA\nBCA\nBCA\nPayment to\nAcquirer\nRRN\nQRIS...      NaN
# 235    BCA_44  BCA\nBCA\nRRN\nBCA\nPayment to\nAcquirer\nQRIS...      NaN
# 236    BCA_45  BCA\n&BCA\nRRN\nBCA\nPayment to\nAcquirer\nQRI...      NaN
# 237    BCA_46  BCA\nBCA\nRRN\nBCA\nPayment to\nAcquirer\nQRIS...      NaN
# 238    BCA_47  BCA\n&BCA\nPayment to\nAcquirer\nRRN\nQRIS Pay...      NaN
# 239    BCA_48  BCA\n&BCA\nBCA\nPayment to\nAcquirer\nRRN\nQRI...      NaN
# 240    BCA_49  BCA\nBCA\nRRN\nBCA\nPayment to\nAcquirer\nQRIS...      NaN
# 241    BCA_50  BCA\n&BCA\nBCA\nPayment to\nAcquirer\nRRN\nQRI...      NaN
#
#     Method                              source
# 185    NaN  OCR Dataset - Livin By Mandiri.csv
# 221    NaN             OCR Dataset - MyBCA.csv
# 222    NaN             OCR Dataset - MyBCA.csv
# 223    NaN             OCR Dataset - MyBCA.csv
# 224    NaN             OCR Dataset - MyBCA.csv
# 225    NaN             OCR Dataset - MyBCA.csv
# 226    NaN             OCR Dataset - MyBCA.csv
# 227    NaN             OCR Dataset - MyBCA.csv
# 228    NaN             OCR Dataset - MyBCA.csv
# 229    NaN             OCR Dataset - MyBCA.csv
# 230    NaN             OCR Dataset - MyBCA.csv
# 231    NaN             OCR Dataset - MyBCA.csv
# 232    NaN             OCR Dataset - MyBCA.csv
# 233    NaN             OCR Dataset - MyBCA.csv
# 234    NaN             OCR Dataset - MyBCA.csv
# 235    NaN             OCR Dataset - MyBCA.csv
# 236    NaN             OCR Dataset - MyBCA.csv
# 237    NaN             OCR Dataset - MyBCA.csv
# 238    NaN             OCR Dataset - MyBCA.csv
# 239    NaN             OCR Dataset - MyBCA.csv
# 240    NaN             OCR Dataset - MyBCA.csv
# 241    NaN             OCR Dataset - MyBCA.csv

# %%
#drop yang null
df = df.dropna().reset_index(drop=True)

df.isnull().sum()
# Out:
# Nama File    0
# Hasil OCR    0
# Kategori     0
# Method       0
# source       0
# dtype: int64

# %%
df['Kategori'].value_counts()
# Out:
# Kategori
# Shopping              83
# Transport             78
# Other                 71
# Food and Beverages    66
# Bills                 10
# Entertaiment           6
# Education              5
# Health                 1
# Name: count, dtype: int64

# %%
df['Method'].value_counts()
# Out:
# Method
# E-WALLET    150
# TRANSFER     93
# QRIS         71
# VA            6
# Name: count, dtype: int64

# %%
# karena Bills, Entertaiment, Education, Health sedikit, kita gabung menjadi Lifestyle/Reccurring
df['Kategori'] = df['Kategori'].replace({
    'Bills': 'Lifestyle/Reccurring',
    'Entertaiment': 'Lifestyle/Reccurring',
    'Education': 'Lifestyle/Reccurring',
    'Health': 'Lifestyle/Reccurring'
})

# %%
df['Kategori'].value_counts()
# Out:
# Kategori
# Shopping                83
# Transport               78
# Other                   71
# Food and Beverages      66
# Lifestyle/Reccurring    22
# Name: count, dtype: int64

# %%
import re

def clean_ocr_basic(text):
    text = str(text)
    text = text.lower()
    text = text.replace("\n", " ")
    text = re.sub(r"\s+", " ", text)   # spasi ganda
    return text.strip()

def remove_ui_noise(text):
    noise_patterns = [
        r"id transaksi",
        r"transaksi berhasil",
        r"success",
        r"ref no",
    ]
    for p in noise_patterns:
        text = re.sub(p, " ", text)
    return re.sub(r"\s+", " ", text).strip()


def clean_ocr(text):
    text = clean_ocr_basic(text)
    text = remove_ui_noise(text)
    return text

df['Hasil OCR'] = df['Hasil OCR'].apply(clean_ocr)
df
# Out:
#      Nama File                                          Hasil OCR  \
# 0      Jago_01  dimsum nat food rp13.500 2387821914 sumber aku...
# 1      Jago_02  kios talenta rp2.200 2340147702 sumber akun ke...
# 2      Jago_03  jus mbak yuli rp11.000 2365882380 sumber akun ...
# 3      Jago_04  kedai yo rp6.000 2350877o19 sumber akun kezia ...
# 4      Jago_05  sumarni, otomotif bogor rp13.000 2574180843 su...
# ..         ...                                                ...
# 315  Shopee_46  8:14 & 9 <rincian pembayaran bayar ke transaks...
# 316  Shopee_47  8:08 9 < rincian pembayaran bayar ke transaksi...
# 317  Shopee_48  8:14 9 <rincian pembayaran bayar ke s shopee f...
# 318  Shopee_49  9:36 l 00:23 ( rincian pembayaran bayar ke bon...
# 319  Shopee_50  10:07 l 31:54 ( rincian pembayaran bayar ke bo...
#
#                Kategori    Method                        source
# 0    Food and Beverages      QRIS   OCR Dataset - Bank Jago.csv
# 1              Shopping      QRIS   OCR Dataset - Bank Jago.csv
# 2    Food and Beverages      QRIS   OCR Dataset - Bank Jago.csv
# 3    Food and Beverages      QRIS   OCR Dataset - Bank Jago.csv
# 4             Transport      QRIS   OCR Dataset - Bank Jago.csv
# ..                  ...       ...                           ...
# 315            Shopping  E-WALLET  OCR Dataset - Shopee Pay.csv
# 316            Shopping  E-WALLET  OCR Dataset - Shopee Pay.csv
# 317  Food and Beverages  E-WALLET  OCR Dataset - Shopee Pay.csv
# 318            Shopping      QRIS  OCR Dataset - Shopee Pay.csv
# 319            Shopping      QRIS  OCR Dataset - Shopee Pay.csv
#
# [320 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split

X = df[["Hasil OCR"]]
y = df["Kategori"]

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=26, stratify=y
)

# %%
from sklearn.pipeline import Pipeline

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import FunctionTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression

# Transformer untuk bersihin kolom teks (inputnya 2D: DataFrame 1 kolom)
# 2) Define vectorizers
word_tfidf = TfidfVectorizer(
    ngram_range=(1, 2),
    max_features=10000,
    min_df=2,
    sublinear_tf=True
)

char_tfidf = TfidfVectorizer(
    analyzer="char_wb",
    ngram_range=(3, 5),
    min_df=2,
    sublinear_tf=True
)

# 3) Gabung word + char features dari kolom ke-0 (single text column)
features = ColumnTransformer(
    transformers=[
        ("word", word_tfidf, 0),
        ("char", char_tfidf, 0),
    ],
    remainder="drop"
)

# 4) Final pipeline
pipeline = Pipeline([
    ("feat", features),
    ("clf", LogisticRegression(
        max_iter=2000,
        class_weight="balanced",
        solver="lbfgs"   # atau saga
    ))
])

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('feat',
#                  ColumnTransformer(transformers=[('word',
#                                                   TfidfVectorizer(max_features=10000,
#                                                                   min_df=2,
#                                                                   ngram_range=(1,
#                                                                                2),
#                                                                   sublinear_tf=True),
#                                                   0),
#                                                  ('char',
#                                                   TfidfVectorizer(analyzer='char_wb',
#                                                                   min_df=2,
#                                                                   ngram_range=(3,
#                                                                                5),
#                                                                   sublinear_tf=True),
#                                                   0)])),
#                 ('clf',
#                  LogisticRegression(class_weight='balanced', max_iter=2000))])

# %%
from sklearn.metrics import classification_report

y_pred = pipeline.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#                       precision    recall  f1-score   support
#
#   Food and Beverages       0.71      0.85      0.77        20
# Lifestyle/Reccurring       0.43      0.43      0.43         7
#                Other       0.87      0.95      0.91        21
#             Shopping       1.00      0.76      0.86        25
#            Transport       0.87      0.87      0.87        23
#
#             accuracy                           0.82        96
#            macro avg       0.78      0.77      0.77        96
#         weighted avg       0.84      0.82      0.82        96

# %%
import sklearn, inspect
from sklearn.linear_model import LogisticRegression

print("sklearn version:", sklearn.__version__)
print("LogisticRegression object:", LogisticRegression)
print("signature:", inspect.signature(LogisticRegression))
# Out:
# sklearn version: 1.8.0
# LogisticRegression object: <class 'sklearn.linear_model._logistic.LogisticRegression'>
# signature: (penalty='deprecated', *, C=1.0, l1_ratio=0.0, dual=False, tol=0.0001, fit_intercept=True, intercept_scaling=1, class_weight=None, random_state=None, solver='lbfgs', max_iter=100, verbose=0, warm_start=False, n_jobs=None)
